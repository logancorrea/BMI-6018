# %%
import pandas as pd
df = pd.read_csv("breast-cancer.data", header=None)
df.columns = ['Class', 'age', 'menopause', 'tumor-size', 'inv-nodes', 'node-caps', 'deg-malig', 'breast', 'breast-quad', 'irradiat']
df
# Out:
#                     Class    age menopause tumor-size inv_nodes node-caps  \
# 0    no-recurrence-events  30-39   premeno      30-34       0-2        no
# 1    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 2    no-recurrence-events  40-49   premeno      20-24       0-2        no
# 3    no-recurrence-events  60-69      ge40      15-19       0-2        no
# 4    no-recurrence-events  40-49   premeno        0-4       0-2        no
# ..                    ...    ...       ...        ...       ...       ...
# 281     recurrence-events  30-39   premeno      30-34       0-2        no
# 282     recurrence-events  30-39   premeno      20-24       0-2        no
# 283     recurrence-events  60-69      ge40      20-24       0-2        no
# 284     recurrence-events  40-49      ge40      30-34       3-5        no
# 285     recurrence-events  50-59      ge40      30-34       3-5        no
#
#      deg-malig breast breast-quad irradiat
# ...

# %%
#Melt
melt_columns = ['age', 'menopause', 'tumor-size']
df_melted = df.melt(id_vars=melt_columns, var_name='variable', value_name='value')
df_melted
# Out:
#         age menopause tumor-size  variable                 value
# 0     30-39   premeno      30-34     Class  no-recurrence-events
# 1     40-49   premeno      20-24     Class  no-recurrence-events
# 2     40-49   premeno      20-24     Class  no-recurrence-events
# 3     60-69      ge40      15-19     Class  no-recurrence-events
# 4     40-49   premeno        0-4     Class  no-recurrence-events
# ...     ...       ...        ...       ...                   ...
# 1997  30-39   premeno      30-34  irradiat                    no
# 1998  30-39   premeno      20-24  irradiat                   yes
# 1999  60-69      ge40      20-24  irradiat                    no
# 2000  40-49      ge40      30-34  irradiat                    no
# 2001  50-59      ge40      30-34  irradiat                    no
#
# [2002 rows x 5 columns]

# %%
#Pivot
df1 = df.drop_duplicates(subset=['age'])
df_pivot = df1.pivot(index='age', columns='breast-quad', values='irradiat')
df_pivot
# Out:
# breast-quad left_low left_up right_up
# age
# 20-29            NaN     NaN       no
# 30-39             no     NaN      NaN
# 40-49            NaN     NaN       no
# 50-59             no     NaN      NaN
# 60-69            NaN      no      NaN
# 70-79            NaN      no      NaN

# %%
#Aggregate
df.agg({ 'age' : "count", 'deg-malig' : "max", 'tumor-size' : "min"})
# Out:
# age           286
# deg-malig       3
# tumor-size    0-4
# dtype: object

# %%
#Iteration
for index, row in df.iterrows():
    print(index, row['age'])
# Out:
# 0 30-39
# 1 40-49
# 2 40-49
# 3 60-69
# 4 40-49
# 5 60-69
# 6 50-59
# 7 60-69
# 8 40-49
# 9 40-49
# 10 40-49
# 11 50-59
# 12 60-69
# 13 50-59
# 14 40-49
# 15 60-69
# 16 40-49
# 17 50-59
# 18 60-69
# 19 50-59
# 20 50-59
# 21 60-69
# 22 30-39
# 23 50-59
# 24 50-59
# 25 40-49
# 26 50-59
# 27 60-69
# 28 40-49
# 29 60-69
# 30 50-59
# 31 50-59
# 32 50-59
# 33 50-59
# 34 50-59
# 35 30-39
# 36 50-59
# 37 50-59
# 38 40-49
# 39 40-49
# 40 50-59
# 41 60-69
# 42 60-69
# 43 40-49
# 44 50-59
# 45 50-59
# 46 40-49
# 47 50-59
# 48 40-49
# 49 40-49
# 50 50-59
# 51 30-39
# 52 50-59
# 53 70-79
# 54 70-79
# 55 70-79
# 56 50-59
# 57 50-59
# 58 60-69
# 59 60-69
# 60 40-49
# 61 40-49
# 62 50-59
# 63 20-29
# 64 40-49
# 65 40-49
# 66 40-49
# 67 50-59
# 68 50-59
# 69 60-69
# 70 60-69
# 71 40-49
# 72 60-69
# 73 50-59
# 74 30-39
# 75 50-59
# 76 50-59
# 77 30-39
# 78 50-59
# 79 40-49
# 80 50-59
# 81 60-69
# 82 60-69
# 83 50-59
# 84 40-49
# 85 50-59
# 86 60-69
# 87 70-79
# 88 50-59
# 89 40-49
# 90 30-39
# ...

# %%
#Groupby
grouped = df.groupby('Class')
max = grouped['tumor-size'].max()
max
# Out:
# Class
# no-recurrence-events    50-54
# recurrence-events       50-54
# Name: tumor-size, dtype: object
