# %%
"" An introduction to the library and its sources as comments. (10 Points)
Advantages, limitations of using the library also provided as comments (10 Points)"

# %%
#BioPython is an open-source python library that contains tools for biological computation. The source code is currently released under the Biopython License. Advantages of BioPython include extensive file format functionality and online database access to provide easy manipulation of biological sequence data. One disadvantage of BioPython is that it's performance may not be optimized for specialized tasks that might users to use higher-level coding languages.

# %%
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord

# Read the FASTA file
fasta_file_path = r"C:\Users\logan\Documents\Intro to Programming\M11\fake_fasta.fasta"
records = SeqIO.to_dict(SeqIO.parse(fasta_file_path, "fasta"))

# Translate each sequence and create new SeqRecord objects
translated_records = []
for record_id, record in records.items():
    translated_sequence = str(record.seq.translate())
    translated_record = SeqRecord(Seq(translated_sequence), id=record_id, description=record.description)
    translated_records.append(translated_record)

# Print translated sequences
for translated_record in translated_records:
    print(f"ID: {translated_record.id}")
    print(f"Description: {translated_record.description}")
    print(f"Translated Sequence: {translated_record.seq}")
    print("\n")
# Out:
# ID: Sequence1
# Description: Sequence1 <unknown description>
# Translated Sequence:
#
#
# ID: Sample_1
# Description: Sample_1
# Translated Sequence:
#
#
# ID: Sequence2
# Description: Sequence2 <unknown description>
# Translated Sequence: SFQDRTSTLADRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence3
# Description: Sequence3 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSIDR
#
#
# ID: Sequence4
# Description: Sequence4 <unknown description>
# Translated Sequence: RSIDRSIDRSIDRSIDRSIDRSIDRSIDRSI
#
#
# ID: Sequence5
# Description: Sequence5 <unknown description>
# Translated Sequence: DRSIDRSIDRSIDRSIDRSIDRSIDRSIDRS
#
#
# ID: Sequence6
# Description: Sequence6 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence7
# Description: Sequence7 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence8
# Description: Sequence8 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence9
# Description: Sequence9 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence10
# Description: Sequence10 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence11
# Description: Sequence11 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence12
# Description: Sequence12 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence13
# Description: Sequence13 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence14
# Description: Sequence14 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence15
# Description: Sequence15 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence16
# Description: Sequence16 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence17
# Description: Sequence17 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence18
# Description: Sequence18 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence19
# Description: Sequence19 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence20
# Description: Sequence20 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence21
# Description: Sequence21 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence22
# Description: Sequence22 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence23
# Description: Sequence23 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence24
# Description: Sequence24 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence25
# Description: Sequence25 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence26
# Description: Sequence26 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence27
# Description: Sequence27 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence28
# Description: Sequence28 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence29
# Description: Sequence29 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence30
# Description: Sequence30 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence31
# Description: Sequence31 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence32
# Description: Sequence32 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDRSID
#
#
# ID: Sequence33
# Description: Sequence33 <unknown description>
# Translated Sequence: IDRSIDRSIDRSIDRSIDRSIDRSIDR
